# %%
'''
Data Wrangling
Problem Statement: Data Wrangling on Real Estate Market
Dataset: &quot;RealEstate_Prices.csv&quot;
Description: The dataset contains information about housing prices in a specific real
estate
market. It includes various attributes such as property characteristics, location, sale
prices,
and other relevant features. The goal is to perform data wrangling to gain insights into
the
factors influencing housing prices and prepare the dataset for further analysis or
modeling.
Tasks to Perform:
1. Import the &quot;RealEstate_Prices.csv&quot; dataset. Clean column names by removing spaces,
special characters, or renaming them for clarity.
2. Handle missing values in the dataset, deciding on an appropriate strategy (e.g.,
imputation or removal).
3. Perform data merging if additional datasets with relevant information are available
(e.g., neighborhood demographics or nearby amenities).
4. Filter and subset the data based on specific criteria, such as a particular time period,
property type, or location.
5. Handle categorical variables by encoding them appropriately (e.g., one-hot encoding
or label encoding) for further analysis.
6. Aggregate the data to calculate summary statistics or derived metrics such as average
sale prices by neighborhood or property type.
7. Identify and handle outliers or extreme values in the data that may affect the analysis
or modeling process.
'''
None

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# 1. Import the RealEstate_Prices.csv dataset. Clean column names by removing spaces,
# special characters, or renaming them for clarity.
data = pd.read_csv('Real estate.csv')
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]

# %%
data.columns = [
    'ID',
    'TransactionDate',
    'HouseAge',
    'DistanceToMRT',
    'ConvenienceStores',
    'Latitude',
    'Longitude',
    'HousePricePerUnitArea'
]
data
# Out:
#       ID  TransactionDate  HouseAge  DistanceToMRT  ConvenienceStores  \
# 0      1         2012.917      32.0       84.87882                 10
# 1      2         2012.917      19.5      306.59470                  9
# 2      3         2013.583      13.3      561.98450                  5
# 3      4         2013.500      13.3      561.98450                  5
# 4      5         2012.833       5.0      390.56840                  5
# ..   ...              ...       ...            ...                ...
# 409  410         2013.000      13.7     4082.01500                  0
# 410  411         2012.667       5.6       90.45606                  9
# 411  412         2013.250      18.8      390.96960                  7
# 412  413         2013.000       8.1      104.81010                  5
# 413  414         2013.500       6.5       90.45606                  9
#
#      Latitude  Longitude  HousePricePerUnitArea
# 0    24.98298  121.54024                   37.9
# 1    24.98034  121.53951                   42.2
# 2    24.98746  121.54391                   47.3
# 3    24.98746  121.54391                   54.8
# 4    24.97937  121.54245                   43.1
# ..        ...        ...                    ...
# 409  24.94155  121.50381                   15.4
# 410  24.97433  121.54310                   50.0
# 411  24.97923  121.53986                   40.6
# 412  24.96674  121.54067                   52.5
# 413  24.97433  121.54310                   63.9
#
# [414 rows x 8 columns]

# %%
# 2. Handle missing values in the dataset, deciding on an appropriate strategy (e.g.,
# imputation or removal).
data.isnull().sum()
# Out:
# ID                       0
# TransactionDate          0
# HouseAge                 0
# DistanceToMRT            0
# ConvenienceStores        0
# Latitude                 0
# Longitude                0
# HousePricePerUnitArea    0
# dtype: int64

# %%
# 3. Perform data merging if additional datasets with relevant information are available
# (e.g., neighborhood demographics or nearby amenities).

# %%
# 4. Filter and subset the data based on specific criteria, such as a particular time period,
# property type, or location.
filtered_df = data[(data['TransactionDate'] >= 2013) & (data['DistanceToMRT'] <= 500)]
filtered_df
# Out:
#       ID  TransactionDate  HouseAge  DistanceToMRT  ConvenienceStores  \
# 7      8         2013.417      20.3      287.60250                  6
# 10    11         2013.083      34.8      405.21340                  1
# 11    12         2013.333       6.3       90.45606                  9
# 16    17         2013.250       0.0      292.99780                  6
# 18    19         2013.417      16.9      368.13630                  8
# ..   ...              ...       ...            ...                ...
# 404  405         2013.333      16.4      289.32480                  5
# 406  407         2013.167       1.9      372.13860                  7
# 411  412         2013.250      18.8      390.96960                  7
# 412  413         2013.000       8.1      104.81010                  5
# 413  414         2013.500       6.5       90.45606                  9
#
#      Latitude  Longitude  HousePricePerUnitArea
# 7    24.98042  121.54228                   46.7
# 10   24.97349  121.53372                   41.4
# 11   24.97433  121.54310                   58.1
# 16   24.97744  121.54458                   70.1
# 18   24.96750  121.54451                   42.3
# ..        ...        ...                    ...
# 404  24.98203  121.54348                   41.2
# 406  24.97293  121.54026                   40.5
# 411  24.97923  121.53986                   40.6
# 412  24.96674  121.54067                   52.5
# 413  24.97433  121.54310                   63.9
#
# [145 rows x 8 columns]

# %%
# 5. Handle categorical variables by encoding them appropriately (e.g., one-hot encoding
# or label encoding) for further analysis.
# if 'column name' in data.columns:
#     df = pd.get_dummies(data, columns=['column name'], drop_first=True)

# %%
# 6. Aggregate the data to calculate summary statistics or derived metrics such as average
# sale prices by neighborhood or property type.
avg_price_by_stores = data.groupby('ConvenienceStores')['HousePricePerUnitArea'].mean()
print("Average house price per unit area by convenience stores:\n", avg_price_by_stores)
# Out:
# Average house price per unit area by convenience stores:
#  ConvenienceStores
# 0     26.462687
# 1     31.839130
# 2     31.412500
# 3     29.536957
# 4     37.474194
# 5     44.729851
# 6     46.951351
# 7     43.848387
# 8     44.696667
# 9     51.732000
# 10    48.430000
# Name: HousePricePerUnitArea, dtype: float64

# %%
# 7. Identify and handle outliers or extreme values in the data that may affect the analysis
# or modeling process.
plt.figure(figsize=(15, 5))
sns.boxplot(data=data[['HouseAge', 'DistanceToMRT', 'HousePricePerUnitArea']])
plt.title("Boxplots to Identify Outliers")
plt.show()

# Handling outliers by capping values beyond the 95th percentile
for column in ['HouseAge', 'DistanceToMRT', 'HousePricePerUnitArea']:
    upper_limit = data[column].quantile(0.95)
    lower_limit = data[column].quantile(0.05)
    data[column] = np.clip(data[column], lower_limit, upper_limit)

print("Data wrangling complete.")
# Out:
# Data wrangling complete.

# %%
outlier_columns = ['HouseAge', 'DistanceToMRT', 'HousePricePerUnitArea']

# Capping outliers at the 5th and 95th percentiles
for column in outlier_columns:
    lower_limit = data[column].quantile(0.05)
    upper_limit = data[column].quantile(0.95)
    data[column] = np.clip(data[column], lower_limit, upper_limit)

# Verify changes by checking summary statistics
data[outlier_columns].describe()
# Out:
#          HouseAge  DistanceToMRT  HousePricePerUnitArea
# count  414.000000     414.000000             414.000000
# mean    17.654486    1050.723660              37.671842
# std     11.123124    1154.230959              12.104085
# min      1.100000      90.456060              16.626500
# 25%      9.025000     289.324800              27.700000
# 50%     16.100000     492.231300              38.450000
# 75%     28.150000    1454.279000              46.600000
# max     37.712250    4082.015000              59.061250

# %%
# Done
